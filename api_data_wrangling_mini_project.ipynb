# %% [markdown]
# This exercise will require you to pull some data from https://data.nasdaq.com/ (formerly Quandl API).

# %% [markdown]
# As a first step, you will need to register a free account on the https://data.nasdaq.com/ website.

# %% [markdown]
# After you register, you will be provided with a unique API key, that you should store:
#
# *Note*: Use a `.env` file and put your key in there and `python-dotenv` to access it in this notebook.
#
# The code below uses a key that was used when generating this project but has since been deleted. Never submit your keys to source control. There is a `.env-example` file in this repository to illusrtate what you need. Copy that to a file called `.env` and use your own api key in that `.env` file. Make sure you also have a `.gitignore` file with a line for `.env` added to it.
#
# The standard Python gitignore is [here](https://github.com/github/gitignore/blob/master/Python.gitignore) you can just copy that.

# %%
# get api key from your .env file

import os
from dotenv import load_dotenv, dotenv_values

load_dotenv()
API_KEY = os.getenv('NASDAQ_API_KEY')

print(API_KEY)
# Out:
# yz-b4Jj-MsiX_gqbyuNY

# %% [markdown]
# Nasdaq Data has a large number of data sources, but, unfortunately, most of them require a Premium subscription. Still, there are also a good number of free datasets.

# %% [markdown]
# For this mini project, we will focus on equities data from the Frankfurt Stock Exhange (FSE), which is available for free. We'll try and analyze the stock prices of a company called Carl Zeiss Meditec, which manufactures tools for eye examinations, as well as medical lasers for laser eye surgery: https://www.zeiss.com/meditec/int/home.html. The company is listed under the stock ticker AFX_X.

# %% [markdown]
# You can find the detailed Nasdaq Data API instructions here: https://docs.data.nasdaq.com/docs/in-depth-usage

# %% [markdown]
# While there is a dedicated Python package for connecting to the Nasdaq API, we would prefer that you use the *requests* package, which can be easily downloaded using *pip* or *conda*. You can find the documentation for the package here: http://docs.python-requests.org/en/master/

# %% [markdown]
# Finally, apart from the *requests* package, you are encouraged to not use any third party Python packages, such as *pandas*, and instead focus on what's available in the Python Standard Library (the *collections* module might come in handy: https://pymotw.com/3/collections/).
# Also, since you won't have access to DataFrames, you are encouraged to us Python's native data structures - preferably dictionaries, though some questions can also be answered using lists.
# You can read more on these data structures here: https://docs.python.org/3/tutorial/datastructures.html

# %% [markdown]
# Keep in mind that the JSON responses you will be getting from the API map almost one-to-one to Python's dictionaries. Unfortunately, they can be very nested, so make sure you read up on indexing dictionaries in the documentation provided above.

# %%
# First, import the relevant modules
import requests
import collections

# %% [markdown]
# Note: API's can change a bit with each version, for this exercise it is reccomended to use the nasdaq api at `https://data.nasdaq.com/api/v3/`. This is the same api as what used to be quandl so `https://www.quandl.com/api/v3/` should work too.
#
# Hint: We are looking for the `AFX_X` data on the `datasets/FSE/` dataset.

# %%
# Now, call the Nasdaq API and pull out a small sample of the data (only one day) to get a glimpse
# into the JSON structure that will be returned

url = "https://data.nasdaq.com/api/v3/datasets/FSE/AFX_X/data.json?api_key=yz-b4Jj-MsiX_gqbyuNY"

r = requests.get(url, API_KEY)
r.status_code
r.headers
r.headers['Date']
# Out:
# 'Sat, 25 May 2024 21:23:55 GMT'

# %%
# Inspect the JSON structure of the object you created, and take note of how nested it is,
# as well as the overall structure
r.json()
# Out:
# {'dataset_data': {'limit': None,
#   'transform': None,
#   'column_index': None,
#   'column_names': ['Date',
#    'Open',
#    'High',
#    'Low',
#    'Close',
#    'Change',
#    'Traded Volume',
#    'Turnover',
#    'Last Price of the Day',
#    'Daily Traded Units',
#    'Daily Turnover'],
#   'start_date': '2000-06-07',
#   'end_date': '2020-12-01',
#   'frequency': 'daily',
#   'data': [['2020-12-01',
#     112.2,
#     112.2,
#     111.5,
#     112.0,
#     None,
#     51.0,
#     5703.0,
#     None,
#     None,
#     None],
#    ['2020-11-30',
#     111.0,
#     113.6,
#     111.0,
#     112.1,
#     None,
#     315.0,
#     35111.5,
#     None,
#     None,
#     None],
#    ['2020-11-27',
#     111.0,
#     111.5,
#     109.5,
#     111.2,
#     None,
#     155.0,
#     17168.5,
#     None,
#     None,
#     None],
#    ['2020-11-26',
#     111.3,
#     112.0,
#     110.5,
#     111.6,
#     None,
#     254.0,
#     28367.5,
#     None,
#     None,
#     None],
# ...

# %% [markdown]
# These are your tasks for this mini project:
#
# 1. Collect data from the Franfurt Stock Exchange, for the ticker AFX_X, for the whole year 2017 (keep in mind that the date format is YYYY-MM-DD).
# 2. Convert the returned JSON object into a Python dictionary.
# 3. Calculate what the highest and lowest opening prices were for the stock in this period.
# 4. What was the largest change in any one day (based on High and Low price)?
# 5. What was the largest change between any two days (based on Closing Price)?
# 6. What was the average daily trading volume during this year?
# 7. (Optional) What was the median trading volume during this year. (Note: you may need to implement your own function for calculating the median.)

# %%
#Question 1: Collect data from the Franfurt Stock Exchange, for the ticker AFX_X, for the whole year 2017 (keep in mind that the date format is YYYY-MM-DD)
from datetime import datetime
#store the api request as an object
req_obj = r.json()

#prep to convert strings into datas to make searching for dates easier
format_date = '%Y-%m-%d'

#check how python interprets the request object
for key, value in req_obj.items():
    
    ##convert value into a separate dictionary where data containing dates is easily accessible
    dict_obj = dict(value)
    
    #use iterate through the data key and search for years that are equal to 2017
    data = dict_obj['data']
    for x in data:
        
        date = datetime.strptime(x[0], format_date)
        if date.year == 2017:
            print (x)
# Out:
# ['2017-12-29', 51.76, 51.94, 51.45, 51.76, None, 34640.0, 1792304.0, None, None, None]
# ['2017-12-28', 51.65, 51.82, 51.43, 51.6, None, 40660.0, 2099024.0, None, None, None]
# ['2017-12-27', 51.45, 51.89, 50.76, 51.82, None, 57452.0, 2957018.0, None, None, None]
# ['2017-12-22', 51.05, 51.5, 50.92, 51.32, None, 71165.0, 3641949.0, None, None, None]
# ['2017-12-21', 51.16, 51.52, 50.9, 51.4, None, 120649.0, 6179433.0, None, None, None]
# ['2017-12-20', 51.88, 52.04, 51.2, 51.27, None, 50587.0, 2610258.0, None, None, None]
# ['2017-12-19', 52.73, 52.73, 51.07, 51.66, None, 137313.0, 7102361.0, None, None, None]
# ['2017-12-18', 52.37, 52.75, 51.61, 52.62, None, 129733.0, 6770499.0, None, None, None]
# ['2017-12-15', 52.7, 52.7, 51.64, 52.01, None, 204080.0, 10596319.0, None, None, None]
# ['2017-12-14', 53.11, 53.54, 52.15, 52.67, None, 132981.0, 7016953.0, None, None, None]
# ['2017-12-13', 52.64, 53.35, 52.48, 53.09, None, 128434.0, 6801159.0, None, None, None]
# ...

# %%
# Question 2 : Convert the returned JSON object into a Python dictionary.

#copy the lines in Question 1 to do this
#check how python interprets the request object
req_obj = r.json()

for key, value in req_obj.items():
    
    ##convert value into a separate dictionary and print out 
    dict_obj = dict(value)
    
    #print (dict_obj.keys())
    #print(dict_obj.values())
    
    
    ### however the values of the data key is not matched up with the values of the columns key yet....
    ##turn the column names into a list and 
    

    
    ##set the correct amount of column names to match the inputs in the data section
    data_obj_part1 = list(dict_obj['column_names']*5268)
    
    
    ##flatten the list of lists into just a list
    data_obj_part2_step1 = dict_obj['data']
    data_obj_part2_step2= [x for xs in data_obj_part2_step1 for x in xs]
    
    ##now need to combine data points of a key into their own separate lists:
    date_list = []
    open_list = []
    high_list = []
    low_list = []
    close_list = []
    change_list = []
    traded_volume_list = []
    turnover_list = []
    last_price_list = []
    daily_traded_list = []
    daily_turn_list = []
    
    data_obj_part2_step3 = [date_list, open_list, high_list, low_list, close_list, change_list, traded_volume_list, turnover_list, last_price_list, daily_traded_list, daily_turn_list]
    
    y = 0
    for x in range(len(data_obj_part2_step2)):
            data_obj_part2_step3[y].append(data_obj_part2_step2[x])
            y+=1
            if y == 11:
                y = 0
        
    ##use zip to combine the two lists into a dictionary
    
    data_dict = {k: v for k, v in zip(data_obj_part1, data_obj_part2_step3)}
    
    #iterate through the lists and fill the dictionary
    #for x in range(len(data_obj_part1)):
        #data_dict[data_obj_part1[x]] = data_obj_part2_step2[x]
    
    print (data_dict.keys())
    print (data_dict)
# Out:
# dict_keys(['Date', 'Open', 'High', 'Low', 'Close', 'Change', 'Traded Volume', 'Turnover', 'Last Price of the Day', 'Daily Traded Units', 'Daily Turnover'])
# ...

# %%
# Question 3a: Calculate what the highest and lowest opening prices were for the stock in this period.

##get rid of Nones so that you can use comparison operators

for key, value in data_dict.items():
    for x in range(len(value)):
        if value[x] == None:
            value[x] = 0
            

print (max(data_dict['Open']))
# Out:
# 122.1

# %%
#question 3b: calculate the lowest opening price

#remove zeroes as to not factor in the search for the minimum

remove_value = []
for key, value in data_dict.items():
    comp_list = [x for x in value if x != 0]
    data_dict[key]=comp_list
        

print (min(data_dict['Open']))
# Out:
# 4.2

# %%
#question 4: What was the largest change in any one day (based on High and Low price)

#make an empty list to store the high prices to use in an iteration
max_list = []
min_list = []


for x in range(len(data_dict['High'])):
    max_list.append(data_dict['High'][x])
    
#make an empty list to store the low prices in an iteration
for x in range(len(data_dict['Low'])):
    min_list.append(data_dict['Low'][x])
    
#check that the len of both lists are the same

print (len(max_list) == len(min_list))

##it is true so that means the days are in both keys are in sync with each other and we can compare indexes safely of both lists

#make an empty list of differences between highs and lows

high_low_diff = []

for x in range(len(max_list)):
    diff = max_list[x] - min_list[x]
    high_low_diff.append(diff)
    
print (max(high_low_diff))
# Out:
# True
# 14.099999999999994

# %%
#5: What was the largest change between any two days (based on Closing Price)?

#make an empty list to store the values of the closing value in an iteration
diff_list_1 = []
#make an empty list to store the differences between closing values from day to day
actual_diff_list = []

#iterate over the 
for x in range(len(data_dict['Close'])):
    diff_list.append(data_dict['Close'][x])
    if x > 1:
        diff = (data_dict['Close'][x])-(data_dict['Close'][x-1])
        actual_diff_list.append(diff)
        
print (max(actual_diff_list))
# Out:
# 8.950000000000003

# %%
#6: What was the average daily trading volume during this year? --- just do 2020 as it is the most recent year

#check that the length of the data key and the trading volume key are the same

print (len(data_dict['Date']),len(data_dict['Traded Volume']))

#they are not equal, but if you inspect the order of values in the original unedited list of traded volume values, all of the zeros come in at the tail of the values, so it will be okay to use index for just the most recent values of 2020
format_date = '%Y-%m-%d'

#since 2020 are the first values, and its already in chronological order, just use the count of the values that have 2020 in order to make index for trading volume
count = 0
for x in (data_dict['Date']):
    
    date = datetime.strptime(x, format_date)
    if date.year == 2020:
        count += 1
        
#print (count) print shows that the first 235 items are  in 2020

sum_traded_2020 = sum(data_dict['Traded Volume'][:235])

avg_2020 = sum_traded_2020/235

print (avg_2020)
# Out:
# 5268 5268
# 126294.17446808511

# %%
# Question 7 What was the median trading volume during this year. (Note: you may need to implement your own function for calculating the median.)

#turn traded volume values into a sorted lsit
traded_volume_list = []

for x in data_dict['Traded Volume']:
    traded_volume_list.append(x)
    
sort_traded = sorted(traded_volume_list)


#find length of the sorted list to find the middle index

len_traded_volume = len(sort_traded)

index_for_median = len_traded_volume/2

#print (index_for_median)

##since the index, when printed, is a whole number (1956.... but really index is 1955 because indices start at 0), must take the average of the values at index 1954 and 1955
median = (sort_traded[1955]+sort_traded[1954])/2
print (median)
# Out:
# 58283.0
